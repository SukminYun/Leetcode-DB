# %% [markdown]
# ### Submission at 2026-02-03 14:43:21

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        index = 0
        print("hello")
        for s in range(len(nums)):
            if(nums[index] != nums[s]):
                index += 1
                nums[index] = nums[s]
                
        return index+1

# %% [markdown]
# ### Submission at 2026-02-03 14:45:17

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        index = 0

        
        for s in range(len(nums)):
            if(nums[index] != nums[s]):
                index += 1
                nums[index] = nums[s]
                
        return index+1

# %% [markdown]
# ### Submission at 2026-02-03 14:48:11

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        index = 0
        print("hi")
        for s in range(len(nums)):
            if(nums[index] != nums[s]):
                index += 1
                nums[index] = nums[s]
                
        return index+1

# %% [markdown]
# ### Submission at 2026-02-03 14:51:05

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        index = 0

        
        for s in range(len(nums)):
            if(nums[index] != nums[s]):
                index += 1
                nums[index] = nums[s]
                
        return index+1

# %% [markdown]
# ### Submission at 2026-02-03 14:51:17

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        index = 0
        print("hello")
        for s in range(len(nums)):
            if(nums[index] != nums[s]):
                index += 1
                nums[index] = nums[s]
                
        return index+1

# %% [markdown]
# ### Submission at 2026-02-03 14:51:23

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        index = 0
        print("hello")
        for s in range(len(nums)):
            if(nums[index] != nums[s]):
                index += 1
                nums[index] = nums[s]
                
        return index+1

# %% [markdown]
# ### Submission at 2026-02-03 14:54:12

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        index = 0
        print("hello")
        for s in range(len(nums)):
            if(nums[index] != nums[s]):
                index += 1
                nums[index] = nums[s]
                
        return index+1
